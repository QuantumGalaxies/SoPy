# %%
# lame training wheels
from sys import path
path += ['..']
#

# %%
import sopy as sp
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# 2025-05-10 07:49:23.730035: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-10 07:49:23.739951: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746881363.751989    5496 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746881363.755512    5496 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-10 07:49:23.767399: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
lattices = [np.arange(-10,10.1,0.1)]

v_r = sp.Vector()
for position in [0]:
    v_r += sp.Vector().gaussian(a = 1,positions = [position],sigmas = [1], ls = [0], wavenumbers= [10], phis = [0], lattices = lattices)

#v_r = sp.Vector().delta( a = 1 , positions = [0.0], spacings = [1.6] , lattices = lattices , wavenumbers = [5.], phis = [0.])

# %%
v = sp.Operand( v_r.decompose(1), sp.Vector() ) 
v_r.dot(v_r)
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=1.0>

# %%
plt.plot(lattices[0],v.re.decompose(1)[1][0], label = 'v')
plt.legend()

# %%
v.exp_i([1.]).cot(v)
#(0.7788007830714049-1.6511779765740195e-17j)
# Out:
# (0.7788007830714052+4.450897489540757e-17j)

# %%
K = np.arange(0.,np.pi/0.1,1)

# %%
plt.plot(K,[ np.abs(v.exp_i([k]).cot(v)) for k in K], label = 'v')
plt.legend()
